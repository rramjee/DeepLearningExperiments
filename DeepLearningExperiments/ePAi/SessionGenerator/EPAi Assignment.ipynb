# %%
from AssignmentCode import *

# %% [markdown]
# # Goal 1
#
# ### Create a lazy iterator that will return a named tuple of the data in each row. The data types should be appropriate - i.e. if the column is a date, you should be storing dates in the named tuple, if the field is an integer, then it should be stored as an integer, etc.

# %%
get_ticket = iter(get_tickets())

for i in get_ticket:
    print(i, end ="\n")
# Out:
# Ticket(Summons_Number=4006478550, Plate_ID='VAD7274', Registration_State='VA', Plate_Type='PAS', Issue_Date=datetime.datetime(2016, 10, 5, 0, 0), Violation_Code=5, Vehicle_Body_Type='4D', Vehicle_Make='BMW', Violation_Description='BUS LANE VIOLATION')
# Ticket(Summons_Number=4006462396, Plate_ID='22834JK', Registration_State='NY', Plate_Type='COM', Issue_Date=datetime.datetime(2016, 9, 30, 0, 0), Violation_Code=5, Vehicle_Body_Type='VAN', Vehicle_Make='CHEVR', Violation_Description='BUS LANE VIOLATION')
# Ticket(Summons_Number=4007117810, Plate_ID='21791MG', Registration_State='NY', Plate_Type='COM', Issue_Date=datetime.datetime(2017, 4, 10, 0, 0), Violation_Code=5, Vehicle_Body_Type='VAN', Vehicle_Make='DODGE', Violation_Description='BUS LANE VIOLATION')
# Ticket(Summons_Number=4006265037, Plate_ID='FZX9232', Registration_State='NY', Plate_Type='PAS', Issue_Date=datetime.datetime(2016, 8, 23, 0, 0), Violation_Code=5, Vehicle_Body_Type='SUBN', Vehicle_Make='FORD', Violation_Description='BUS LANE VIOLATION')
# Ticket(Summons_Number=4006535600, Plate_ID='N203399C', Registration_State='NY', Plate_Type='OMT', Issue_Date=datetime.datetime(2016, 10, 19, 0, 0), Violation_Code=5, Vehicle_Body_Type='SUBN', Vehicle_Make='FORD', Violation_Description='BUS LANE VIOLATION')
# Ticket(Summons_Number=4007156700, Plate_ID='92163MG', Registration_State='NY', Plate_Type='COM', Issue_Date=datetime.datetime(2017, 4, 13, 0, 0), Violation_Code=5, Vehicle_Body_Type='VAN', Vehicle_Make='FRUEH', Violation_Description='BUS LANE VIOLATION')
# Ticket(Summons_Number=4006687989, Plate_ID='MIQ600', Registration_State='SC', Plate_Type='PAS', Issue_Date=datetime.datetime(2016, 11, 21, 0, 0), Violation_Code=5, Vehicle_Body_Type='VN', Vehicle_Make='HONDA', Violation_Description='BUS LANE VIOLATION')
# Ticket(Summons_Number=4006943052, Plate_ID='2AE3984', Registration_State='MD', Plate_Type='PAS', Issue_Date=datetime.datetime(2017, 2, 1, 0, 0), Violation_Code=5, Vehicle_Body_Type='SW', Vehicle_Make='LINCO', Violation_Description='BUS LANE VIOLATION')
# Ticket(Summons_Number=4007306795, Plate_ID='HLG4926', Registration_State='NY', Plate_Type='PAS', Issue_Date=datetime.datetime(2017, 5, 30, 0, 0), Violation_Code=5, Vehicle_Body_Type='SUBN', Vehicle_Make='TOYOT', Violation_Description='BUS LANE VIOLATION')
# Ticket(Summons_Number=4007124590, Plate_ID='T715907C', Registration_State='NY', Plate_Type='OMT', Issue_Date=datetime.datetime(2017, 4, 3, 0, 0), Violation_Code=5, Vehicle_Body_Type='SUBN', Vehicle_Make='TOYOT', Violation_Description='BUS LANE VIOLATION')
# Ticket(Summons_Number=5096061966, Plate_ID='HRC9475', Registration_State='NY', Plate_Type='PAS', Issue_Date=datetime.datetime(2017, 4, 18, 0, 0), Violation_Code=7, Vehicle_Body_Type='SUBN', Vehicle_Make='CADIL', Violation_Description='FAILURE TO STOP AT RED LIGHT')
# Ticket(Summons_Number=5094070400, Plate_ID='DYP8042', Registration_State='NY', Plate_Type='PAS', Issue_Date=datetime.datetime(2016, 10, 26, 0, 0), Violation_Code=7, Vehicle_Body_Type='SUBN', Vehicle_Make='CHEVR', Violation_Description='FAILURE TO STOP AT RED LIGHT')
# Ticket(Summons_Number=5094906770, Plate_ID='G30ESY', Registration_State='NJ', Plate_Type='PAS', Issue_Date=datetime.datetime(2017, 1, 1, 0, 0), Violation_Code=7, Vehicle_Body_Type='WAGO', Vehicle_Make='CHRYS', Violation_Description='FAILURE TO STOP AT RED LIGHT')
# Ticket(Summons_Number=5093319363, Plate_ID='GGT8868', Registration_State='NY', Plate_Type='PAS', Issue_Date=datetime.datetime(2016, 9, 6, 0, 0), Violation_Code=7, Vehicle_Body_Type='SUBN', Vehicle_Make='CHRYS', Violation_Description='FAILURE TO STOP AT RED LIGHT')
# Ticket(Summons_Number=5092638849, Plate_ID='107DDD', Registration_State='NY', Plate_Type='SPO', Issue_Date=datetime.datetime(2016, 7, 20, 0, 0), Violation_Code=7, Vehicle_Body_Type='SUBN', Vehicle_Make='DODGE', Violation_Description='FAILURE TO STOP AT RED LIGHT')
# Ticket(Summons_Number=5093455337, Plate_ID='ENQT55', Registration_State='FL', Plate_Type='PAS', Issue_Date=datetime.datetime(2016, 9, 12, 0, 0), Violation_Code=7, Vehicle_Body_Type='VN', Vehicle_Make='DODGE', Violation_Description='FAILURE TO STOP AT RED LIGHT')
# Ticket(Summons_Number=5094961366, Plate_ID='GSU4156', Registration_State='OH', Plate_Type='PAS', Issue_Date=datetime.datetime(2017, 1, 7, 0, 0), Violation_Code=7, Vehicle_Body_Type='4S', Vehicle_Make='DODGE', Violation_Description='FAILURE TO STOP AT RED LIGHT')
# Ticket(Summons_Number=5092906534, Plate_ID='V84FXV', Registration_State='NJ', Plate_Type='PAS', Issue_Date=datetime.datetime(2016, 8, 7, 0, 0), Violation_Code=7, Vehicle_Body_Type='WAGO', Vehicle_Make='FIR', Violation_Description='FAILURE TO STOP AT RED LIGHT')
# Ticket(Summons_Number=5093620865, Plate_ID='AD80228', Registration_State='AZ', Plate_Type='PAS', Issue_Date=datetime.datetime(2016, 9, 24, 0, 0), Violation_Code=7, Vehicle_Body_Type='TK', Vehicle_Make='FORD', Violation_Description='FAILURE TO STOP AT RED LIGHT')
# Ticket(Summons_Number=5092733548, Plate_ID='EVX4041', Registration_State='NY', Plate_Type='PAS', Issue_Date=datetime.datetime(2016, 7, 26, 0, 0), Violation_Code=7, Vehicle_Body_Type='SUBN', Vehicle_Make='FORD', Violation_Description='FAILURE TO STOP AT RED LIGHT')
# Ticket(Summons_Number=5095995530, Plate_ID='EMK5934', Registration_State='NY', Plate_Type='PAS', Issue_Date=datetime.datetime(2017, 4, 13, 0, 0), Violation_Code=7, Vehicle_Body_Type='VAN', Vehicle_Make='GMC', Violation_Description='FAILURE TO STOP AT RED LIGHT')
# Ticket(Summons_Number=5092750364, Plate_ID='DPH8955', Registration_State='NY', Plate_Type='PAS', Issue_Date=datetime.datetime(2016, 7, 27, 0, 0), Violation_Code=7, Vehicle_Body_Type='SUBN', Vehicle_Make='HONDA', Violation_Description='FAILURE TO STOP AT RED LIGHT')
# Ticket(Summons_Number=5094658001, Plate_ID='GCF1897', Registration_State='NY', Plate_Type='PAS', Issue_Date=datetime.datetime(2016, 12, 10, 0, 0), Violation_Code=7, Vehicle_Body_Type='4DSD', Vehicle_Make='HONDA', Violation_Description='FAILURE TO STOP AT RED LIGHT')
# Ticket(Summons_Number=5092833786, Plate_ID='HCS9434', Registration_State='NY', Plate_Type='PAS', Issue_Date=datetime.datetime(2016, 8, 3, 0, 0), Violation_Code=7, Vehicle_Body_Type='SUBN', Vehicle_Make='HONDA', Violation_Description='FAILURE TO STOP AT RED LIGHT')
# Ticket(Summons_Number=5096484040, Plate_ID='HHS1641', Registration_State='NY', Plate_Type='PAS', Issue_Date=datetime.datetime(2017, 5, 17, 0, 0), Violation_Code=7, Vehicle_Body_Type='SUBN', Vehicle_Make='HONDA', Violation_Description='FAILURE TO STOP AT RED LIGHT')
# Ticket(Summons_Number=5095797586, Plate_ID='KHE1889', Registration_State='PA', Plate_Type='PAS', Issue_Date=datetime.datetime(2017, 3, 28, 0, 0), Violation_Code=7, Vehicle_Body_Type='SDN', Vehicle_Make='HONDA', Violation_Description='FAILURE TO STOP AT RED LIGHT')
# Ticket(Summons_Number=5095799807, Plate_ID='VES2440', Registration_State='VA', Plate_Type='PAS', Issue_Date=datetime.datetime(2017, 3, 29, 0, 0), Violation_Code=7, Vehicle_Body_Type='VAN', Vehicle_Make='HONDA', Violation_Description='FAILURE TO STOP AT RED LIGHT')
# Ticket(Summons_Number=5093533919, Plate_ID='CYU4598', Registration_State='NY', Plate_Type='PAS', Issue_Date=datetime.datetime(2016, 9, 16, 0, 0), Violation_Code=7, Vehicle_Body_Type='SUBN', Vehicle_Make='HYUND', Violation_Description='FAILURE TO STOP AT RED LIGHT')
# Ticket(Summons_Number=5093399735, Plate_ID='DZGT24', Registration_State='FL', Plate_Type='PAS', Issue_Date=datetime.datetime(2016, 9, 4, 0, 0), Violation_Code=7, Vehicle_Body_Type='UT', Vehicle_Make='HYUND', Violation_Description='FAILURE TO STOP AT RED LIGHT')
# Ticket(Summons_Number=5094058873, Plate_ID='GRN3101', Registration_State='NY', Plate_Type='PAS', Issue_Date=datetime.datetime(2016, 10, 29, 0, 0), Violation_Code=7, Vehicle_Body_Type='4DSD', Vehicle_Make='HYUND', Violation_Description='FAILURE TO STOP AT RED LIGHT')
# Ticket(Summons_Number=5094770986, Plate_ID='T668962C', Registration_State='NY', Plate_Type='OMT', Issue_Date=datetime.datetime(2016, 12, 19, 0, 0), Violation_Code=7, Vehicle_Body_Type='4DSD', Vehicle_Make='HYUND', Violation_Description='FAILURE TO STOP AT RED LIGHT')
# Ticket(Summons_Number=5093895611, Plate_ID='GVZ1407', Registration_State='NY', Plate_Type='PAS', Issue_Date=datetime.datetime(2016, 10, 14, 0, 0), Violation_Code=7, Vehicle_Body_Type='4DSD', Vehicle_Make='JAGUA', Violation_Description='FAILURE TO STOP AT RED LIGHT')
# Ticket(Summons_Number=5094185792, Plate_ID='AGM9013', Registration_State='NY', Plate_Type='PAS', Issue_Date=datetime.datetime(2016, 11, 4, 0, 0), Violation_Code=7, Vehicle_Body_Type='SUBN', Vehicle_Make='JEEP', Violation_Description='FAILURE TO STOP AT RED LIGHT')
# Ticket(Summons_Number=5092708219, Plate_ID='F47DZF', Registration_State='NJ', Plate_Type='PAS', Issue_Date=datetime.datetime(2016, 7, 24, 0, 0), Violation_Code=7, Vehicle_Body_Type='4 DR', Vehicle_Make='JEEP', Violation_Description='FAILURE TO STOP AT RED LIGHT')
# Ticket(Summons_Number=5094759954, Plate_ID='GLB8157', Registration_State='NY', Plate_Type='PAS', Issue_Date=datetime.datetime(2016, 12, 19, 0, 0), Violation_Code=7, Vehicle_Body_Type='SUBN', Vehicle_Make='JEEP', Violation_Description='FAILURE TO STOP AT RED LIGHT')
# Ticket(Summons_Number=5093891046, Plate_ID='FJS4033', Registration_State='NY', Plate_Type='PAS', Issue_Date=datetime.datetime(2016, 10, 14, 0, 0), Violation_Code=7, Vehicle_Body_Type='4DSD', Vehicle_Make='LEXUS', Violation_Description='FAILURE TO STOP AT RED LIGHT')
# Ticket(Summons_Number=5093527853, Plate_ID='GYM9809', Registration_State='NY', Plate_Type='PAS', Issue_Date=datetime.datetime(2016, 9, 21, 0, 0), Violation_Code=7, Vehicle_Body_Type='4DSD', Vehicle_Make='LEXUS', Violation_Description='FAILURE TO STOP AT RED LIGHT')
# Ticket(Summons_Number=5096683886, Plate_ID='HCS4873', Registration_State='NY', Plate_Type='PAS', Issue_Date=datetime.datetime(2017, 5, 18, 0, 0), Violation_Code=7, Vehicle_Body_Type='4DSD', Vehicle_Make='LEXUS', Violation_Description='FAILURE TO STOP AT RED LIGHT')
# Ticket(Summons_Number=5096917368, Plate_ID='FZD8593', Registration_State='NY', Plate_Type='PAS', Issue_Date=datetime.datetime(2017, 6, 13, 0, 0), Violation_Code=7, Vehicle_Body_Type='SUBN', Vehicle_Make='ME/BE', Violation_Description='FAILURE TO STOP AT RED LIGHT')
# Ticket(Summons_Number=5094893737, Plate_ID='GER1584', Registration_State='NY', Plate_Type='PAS', Issue_Date=datetime.datetime(2016, 12, 31, 0, 0), Violation_Code=7, Vehicle_Body_Type='4DSD', Vehicle_Make='ME/BE', Violation_Description='FAILURE TO STOP AT RED LIGHT')
# Ticket(Summons_Number=5096249300, Plate_ID='HEM8411', Registration_State='NY', Plate_Type='PAS', Issue_Date=datetime.datetime(2017, 5, 1, 0, 0), Violation_Code=7, Vehicle_Body_Type='4DSD', Vehicle_Make='ME/BE', Violation_Description='FAILURE TO STOP AT RED LIGHT')
# Ticket(Summons_Number=5096958772, Plate_ID='165TRX', Registration_State='CT', Plate_Type='PAS', Issue_Date=datetime.datetime(2017, 6, 16, 0, 0), Violation_Code=7, Vehicle_Body_Type='4W', Vehicle_Make='MERCU', Violation_Description='FAILURE TO STOP AT RED LIGHT')
# Ticket(Summons_Number=5093703217, Plate_ID='HFG4313', Registration_State='NY', Plate_Type='PAS', Issue_Date=datetime.datetime(2016, 9, 30, 0, 0), Violation_Code=7, Vehicle_Body_Type='4DSD', Vehicle_Make='MITSU', Violation_Description='FAILURE TO STOP AT RED LIGHT')
# Ticket(Summons_Number=5094670736, Plate_ID='AXU4790', Registration_State='NY', Plate_Type='PAS', Issue_Date=datetime.datetime(2016, 12, 11, 0, 0), Violation_Code=7, Vehicle_Body_Type='4DSD', Vehicle_Make='NISSA', Violation_Description='FAILURE TO STOP AT RED LIGHT')
# Ticket(Summons_Number=5094094166, Plate_ID='CZM4111', Registration_State='NY', Plate_Type='PAS', Issue_Date=datetime.datetime(2016, 10, 28, 0, 0), Violation_Code=7, Vehicle_Body_Type='4DSD', Vehicle_Make='TOYOT', Violation_Description='FAILURE TO STOP AT RED LIGHT')
# Ticket(Summons_Number=5096723768, Plate_ID='EDN2797', Registration_State='NY', Plate_Type='PAS', Issue_Date=datetime.datetime(2017, 6, 2, 0, 0), Violation_Code=7, Vehicle_Body_Type='4DSD', Vehicle_Make='TOYOT', Violation_Description='FAILURE TO STOP AT RED LIGHT')
# Ticket(Summons_Number=5093209120, Plate_ID='FZT5005', Registration_State='NY', Plate_Type='PAS', Issue_Date=datetime.datetime(2016, 8, 28, 0, 0), Violation_Code=7, Vehicle_Body_Type='4DSD', Vehicle_Make='TOYOT', Violation_Description='FAILURE TO STOP AT RED LIGHT')
# Ticket(Summons_Number=5092469481, Plate_ID='GZH7067', Registration_State='NY', Plate_Type='PAS', Issue_Date=datetime.datetime(2016, 7, 10, 0, 0), Violation_Code=7, Vehicle_Body_Type='SUBN', Vehicle_Make='TOYOT', Violation_Description='FAILURE TO STOP AT RED LIGHT')
# Ticket(Summons_Number=5092451658, Plate_ID='GZH7067', Registration_State='NY', Plate_Type='PAS', Issue_Date=datetime.datetime(2016, 7, 8, 0, 0), Violation_Code=7, Vehicle_Body_Type='SUBN', Vehicle_Make='TOYOT', Violation_Description='FAILURE TO STOP AT RED LIGHT')
# Ticket(Summons_Number=5095356545, Plate_ID='GZM8254', Registration_State='NY', Plate_Type='OMS', Issue_Date=datetime.datetime(2017, 2, 18, 0, 0), Violation_Code=7, Vehicle_Body_Type='SUBN', Vehicle_Make='TOYOT', Violation_Description='FAILURE TO STOP AT RED LIGHT')
# Ticket(Summons_Number=8410006650, Plate_ID='D53AUUN', Registration_State='NJ', Plate_Type='PAS', Issue_Date=datetime.datetime(2016, 10, 21, 0, 0), Violation_Code=9, Vehicle_Body_Type='4DSD', Vehicle_Make='LEXUS', Violation_Description='09-Blocking the Box')
# Ticket(Summons_Number=8534116519, Plate_ID='CES6482', Registration_State='NY', Plate_Type='PAS', Issue_Date=datetime.datetime(2017, 6, 12, 0, 0), Violation_Code=9, Vehicle_Body_Type='SUBN', Vehicle_Make='TOYOT', Violation_Description='09-Blocking the Box')
# Ticket(Summons_Number=8485674984, Plate_ID='T713160C', Registration_State='NY', Plate_Type='OMT', Issue_Date=datetime.datetime(2017, 6, 13, 0, 0), Violation_Code=9, Vehicle_Body_Type='SUBN', Vehicle_Make='TOYOT', Violation_Description='09-Blocking the Box')
# Ticket(Summons_Number=8556557405, Plate_ID='59622JW', Registration_State='NY', Plate_Type='COM', Issue_Date=datetime.datetime(2017, 6, 9, 0, 0), Violation_Code=10, Vehicle_Body_Type='VAN', Vehicle_Make='FORD', Violation_Description='10-No Stopping')
# Ticket(Summons_Number=8071038416, Plate_ID='AM479F', Registration_State='NJ', Plate_Type='PAS', Issue_Date=datetime.datetime(2016, 7, 7, 0, 0), Violation_Code=10, Vehicle_Body_Type='DELV', Vehicle_Make='FRUEH', Violation_Description='10-No Stopping')
# Ticket(Summons_Number=8483087236, Plate_ID='76822MH', Registration_State='NY', Plate_Type='COM', Issue_Date=datetime.datetime(2017, 5, 19, 0, 0), Violation_Code=10, Vehicle_Body_Type='DELV', Vehicle_Make='HIN', Violation_Description='10-No Stopping')
# Ticket(Summons_Number=8481125088, Plate_ID='55179ME', Registration_State='NY', Plate_Type='COM', Issue_Date=datetime.datetime(2017, 4, 10, 0, 0), Violation_Code=10, Vehicle_Body_Type='DELV', Vehicle_Make='NS/OT', Violation_Description='10-No Stopping')
# Ticket(Summons_Number=8506822300, Plate_ID='55106MB', Registration_State='NY', Plate_Type='COM', Issue_Date=datetime.datetime(2017, 5, 31, 0, 0), Violation_Code=10, Vehicle_Body_Type='VAN', Vehicle_Make='WORKH', Violation_Description='10-No Stopping')
# Ticket(Summons_Number=8482331425, Plate_ID='86609MB', Registration_State='NY', Plate_Type='COM', Issue_Date=datetime.datetime(2017, 6, 18, 0, 0), Violation_Code=13, Vehicle_Body_Type='VAN', Vehicle_Make='CHEVR', Violation_Description='13-No Stand (taxi stand)')
# Ticket(Summons_Number=8028246722, Plate_ID='T703619C', Registration_State='NY', Plate_Type='OMT', Issue_Date=datetime.datetime(2016, 9, 15, 0, 0), Violation_Code=13, Vehicle_Body_Type='SUBN', Vehicle_Make='CHEVR', Violation_Description='13-No Stand (taxi stand)')
# Ticket(Summons_Number=8378547530, Plate_ID='FWZ8815', Registration_State='NY', Plate_Type='PAS', Issue_Date=datetime.datetime(2017, 1, 11, 0, 0), Violation_Code=14, Vehicle_Body_Type='2DSD', Vehicle_Make='ACURA', Violation_Description='14-No Standing')
# Ticket(Summons_Number=8489750210, Plate_ID='6DQT356', Registration_State='CA', Plate_Type='PAS', Issue_Date=datetime.datetime(2016, 11, 28, 0, 0), Violation_Code=14, Vehicle_Body_Type='4DSD', Vehicle_Make='AUDI', Violation_Description='14-No Standing')
# Ticket(Summons_Number=1410726095, Plate_ID='DEP4792', Registration_State='NC', Plate_Type='PAS', Issue_Date=datetime.datetime(2016, 7, 15, 0, 0), Violation_Code=14, Vehicle_Body_Type='', Vehicle_Make='BMW', Violation_Description='')
# Ticket(Summons_Number=8421031235, Plate_ID='GGA4266', Registration_State='NY', Plate_Type='PAS', Issue_Date=datetime.datetime(2016, 10, 18, 0, 0), Violation_Code=14, Vehicle_Body_Type='4DSD', Vehicle_Make='BMW', Violation_Description='14-No Standing')
# Ticket(Summons_Number=7730553259, Plate_ID='DLZ8901', Registration_State='NY', Plate_Type='PAS', Issue_Date=datetime.datetime(2016, 9, 26, 0, 0), Violation_Code=14, Vehicle_Body_Type='SUBN', Vehicle_Make='CHEVR', Violation_Description='14-No Standing')
# Ticket(Summons_Number=8498520046, Plate_ID='HKF6916', Registration_State='NY', Plate_Type='PAS', Issue_Date=datetime.datetime(2017, 4, 27, 0, 0), Violation_Code=14, Vehicle_Body_Type='SUBN', Vehicle_Make='CHEVR', Violation_Description='14-No Standing')
# Ticket(Summons_Number=8537807813, Plate_ID='HNF6718', Registration_State='NY', Plate_Type='PAS', Issue_Date=datetime.datetime(2017, 4, 21, 0, 0), Violation_Code=14, Vehicle_Body_Type='SUBN', Vehicle_Make='CHEVR', Violation_Description='14-No Standing')
# Ticket(Summons_Number=8083571465, Plate_ID='KCG9559', Registration_State='PA', Plate_Type='PAS', Issue_Date=datetime.datetime(2016, 12, 22, 0, 0), Violation_Code=14, Vehicle_Body_Type='SUBN', Vehicle_Make='CHEVR', Violation_Description='14-No Standing')
# Ticket(Summons_Number=7536689184, Plate_ID='ZCL5723', Registration_State='PA', Plate_Type='PAS', Issue_Date=datetime.datetime(2017, 1, 26, 0, 0), Violation_Code=14, Vehicle_Body_Type='VAN', Vehicle_Make='CHEVR', Violation_Description='14-No Standing')
# Ticket(Summons_Number=8480505680, Plate_ID='HCT2134', Registration_State='NY', Plate_Type='PAS', Issue_Date=datetime.datetime(2017, 1, 18, 0, 0), Violation_Code=14, Vehicle_Body_Type='SUBN', Vehicle_Make='CHRYS', Violation_Description='14-No Standing')
# Ticket(Summons_Number=8481973580, Plate_ID='28693MH', Registration_State='NY', Plate_Type='COM', Issue_Date=datetime.datetime(2017, 6, 13, 0, 0), Violation_Code=14, Vehicle_Body_Type='VAN', Vehicle_Make='DODGE', Violation_Description='14-No Standing')
# Ticket(Summons_Number=8460500214, Plate_ID='30408MC', Registration_State='NY', Plate_Type='COM', Issue_Date=datetime.datetime(2016, 8, 4, 0, 0), Violation_Code=14, Vehicle_Body_Type='PICK', Vehicle_Make='DODGE', Violation_Description='14-No Standing')
# Ticket(Summons_Number=8482817036, Plate_ID='50501JT', Registration_State='NY', Plate_Type='COM', Issue_Date=datetime.datetime(2017, 4, 11, 0, 0), Violation_Code=14, Vehicle_Body_Type='VAN', Vehicle_Make='DODGE', Violation_Description='14-No Standing')
# Ticket(Summons_Number=8117027999, Plate_ID='83317ME', Registration_State='NY', Plate_Type='COM', Issue_Date=datetime.datetime(2016, 9, 27, 0, 0), Violation_Code=14, Vehicle_Body_Type='VAN', Vehicle_Make='DODGE', Violation_Description='14-No Standing')
# Ticket(Summons_Number=8488121532, Plate_ID='FLX2674', Registration_State='NY', Plate_Type='PAS', Issue_Date=datetime.datetime(2017, 4, 5, 0, 0), Violation_Code=14, Vehicle_Body_Type='2DSD', Vehicle_Make='DODGE', Violation_Description='14-No Standing')
# Ticket(Summons_Number=8543952980, Plate_ID='FSZ8671', Registration_State='NY', Plate_Type='PAS', Issue_Date=datetime.datetime(2017, 4, 21, 0, 0), Violation_Code=14, Vehicle_Body_Type='SUBN', Vehicle_Make='DODGE', Violation_Description='14-No Standing')
# Ticket(Summons_Number=8501806912, Plate_ID='KGP1166', Registration_State='PA', Plate_Type='PAS', Issue_Date=datetime.datetime(2017, 6, 4, 0, 0), Violation_Code=14, Vehicle_Body_Type='VAN', Vehicle_Make='DODGE', Violation_Description='14-No Standing')
# Ticket(Summons_Number=8107542976, Plate_ID='11AH74', Registration_State='MA', Plate_Type='PAS', Issue_Date=datetime.datetime(2017, 1, 29, 0, 0), Violation_Code=14, Vehicle_Body_Type='4DSD', Vehicle_Make='FORD', Violation_Description='14-No Standing')
# Ticket(Summons_Number=8564650320, Plate_ID='29222MK', Registration_State='NY', Plate_Type='COM', Issue_Date=datetime.datetime(2017, 5, 5, 0, 0), Violation_Code=14, Vehicle_Body_Type='VAN', Vehicle_Make='FORD', Violation_Description='14-No Standing')
# Ticket(Summons_Number=8010367576, Plate_ID='30661MA', Registration_State='NY', Plate_Type='COM', Issue_Date=datetime.datetime(2016, 12, 22, 0, 0), Violation_Code=14, Vehicle_Body_Type='VAN', Vehicle_Make='FORD', Violation_Description='14-No Standing')
# Ticket(Summons_Number=8505159536, Plate_ID='41795JX', Registration_State='NY', Plate_Type='COM', Issue_Date=datetime.datetime(2017, 3, 9, 0, 0), Violation_Code=14, Vehicle_Body_Type='VAN', Vehicle_Make='FORD', Violation_Description='14-No Standing')
# Ticket(Summons_Number=7813887440, Plate_ID='44267JZ', Registration_State='NY', Plate_Type='COM', Issue_Date=datetime.datetime(2016, 8, 12, 0, 0), Violation_Code=14, Vehicle_Body_Type='VAN', Vehicle_Make='FORD', Violation_Description='14-No Standing')
# Ticket(Summons_Number=8440509546, Plate_ID='49317JX', Registration_State='NY', Plate_Type='COM', Issue_Date=datetime.datetime(2016, 10, 29, 0, 0), Violation_Code=14, Vehicle_Body_Type='VAN', Vehicle_Make='FORD', Violation_Description='14-No Standing')
# Ticket(Summons_Number=1408575656, Plate_ID='6XWZ969', Registration_State='CA', Plate_Type='PAS', Issue_Date=datetime.datetime(2016, 7, 6, 0, 0), Violation_Code=14, Vehicle_Body_Type='SDN', Vehicle_Make='FORD', Violation_Description='')
# Ticket(Summons_Number=8516853275, Plate_ID='72100MH', Registration_State='NY', Plate_Type='COM', Issue_Date=datetime.datetime(2017, 4, 12, 0, 0), Violation_Code=14, Vehicle_Body_Type='VAN', Vehicle_Make='FORD', Violation_Description='14-No Standing')
# Ticket(Summons_Number=7059924103, Plate_ID='91878MB', Registration_State='NY', Plate_Type='COM', Issue_Date=datetime.datetime(2016, 10, 12, 0, 0), Violation_Code=14, Vehicle_Body_Type='VAN', Vehicle_Make='FORD', Violation_Description='14-No Standing')
# Ticket(Summons_Number=8170085561, Plate_ID='ENM3708', Registration_State='NY', Plate_Type='PAS', Issue_Date=datetime.datetime(2017, 2, 10, 0, 0), Violation_Code=14, Vehicle_Body_Type='SUBN', Vehicle_Make='FORD', Violation_Description='14-No Standing')
# Ticket(Summons_Number=8527511113, Plate_ID='F70GEP', Registration_State='NJ', Plate_Type='PAS', Issue_Date=datetime.datetime(2017, 5, 1, 0, 0), Violation_Code=14, Vehicle_Body_Type='SUBN', Vehicle_Make='FORD', Violation_Description='14-No Standing')
# Ticket(Summons_Number=8511453696, Plate_ID='FSY6987', Registration_State='NY', Plate_Type='PAS', Issue_Date=datetime.datetime(2017, 3, 13, 0, 0), Violation_Code=14, Vehicle_Body_Type='SUBN', Vehicle_Make='FORD', Violation_Description='14-No Standing')
# Ticket(Summons_Number=1413745933, Plate_ID='HCC2829', Registration_State='NY', Plate_Type='PAS', Issue_Date=datetime.datetime(2016, 8, 22, 0, 0), Violation_Code=14, Vehicle_Body_Type='VAN', Vehicle_Make='FORD', Violation_Description='')
# Ticket(Summons_Number=8484882226, Plate_ID='S25DSK', Registration_State='NJ', Plate_Type='PAS', Issue_Date=datetime.datetime(2017, 6, 8, 0, 0), Violation_Code=14, Vehicle_Body_Type='PICK', Vehicle_Make='FORD', Violation_Description='14-No Standing')
# Ticket(Summons_Number=8524054499, Plate_ID='ZRK24R', Registration_State='NJ', Plate_Type='PAS', Issue_Date=datetime.datetime(2017, 3, 18, 0, 0), Violation_Code=14, Vehicle_Body_Type='SUBN', Vehicle_Make='FORD', Violation_Description='14-No Standing')
# Ticket(Summons_Number=1423945281, Plate_ID='2240653', Registration_State='IN', Plate_Type='PAS', Issue_Date=datetime.datetime(2017, 5, 13, 0, 0), Violation_Code=14, Vehicle_Body_Type='', Vehicle_Make='FRUEH', Violation_Description='')
# Ticket(Summons_Number=8577650820, Plate_ID='10632JU', Registration_State='NY', Plate_Type='COM', Issue_Date=datetime.datetime(2017, 6, 20, 0, 0), Violation_Code=14, Vehicle_Body_Type='UTIL', Vehicle_Make='FRUEH', Violation_Description='14-No Standing')
# Ticket(Summons_Number=7056662882, Plate_ID='83038ME', Registration_State='NY', Plate_Type='COM', Issue_Date=datetime.datetime(2016, 9, 21, 0, 0), Violation_Code=14, Vehicle_Body_Type='VAN', Vehicle_Make='FRUEH', Violation_Description='14-No Standing')
# Ticket(Summons_Number=8324025510, Plate_ID='83146ME', Registration_State='NY', Plate_Type='COM', Issue_Date=datetime.datetime(2016, 10, 27, 0, 0), Violation_Code=14, Vehicle_Body_Type='VAN', Vehicle_Make='FRUEH', Violation_Description='14-No Standing')
# Ticket(Summons_Number=8286541110, Plate_ID='85846MD', Registration_State='NY', Plate_Type='COM', Issue_Date=datetime.datetime(2016, 10, 25, 0, 0), Violation_Code=14, Vehicle_Body_Type='VAN', Vehicle_Make='FRUEH', Violation_Description='14-No Standing')
# Ticket(Summons_Number=8270548250, Plate_ID='91028MJ', Registration_State='NY', Plate_Type='COM', Issue_Date=datetime.datetime(2016, 12, 13, 0, 0), Violation_Code=14, Vehicle_Body_Type='DELV', Vehicle_Make='FRUEH', Violation_Description='14-No Standing')
# Ticket(Summons_Number=8480520395, Plate_ID='99886MC', Registration_State='NY', Plate_Type='COM', Issue_Date=datetime.datetime(2017, 6, 19, 0, 0), Violation_Code=14, Vehicle_Body_Type='VAN', Vehicle_Make='FRUEH', Violation_Description='14-No Standing')
# Ticket(Summons_Number=8496410791, Plate_ID='AP338E', Registration_State='NJ', Plate_Type='PAS', Issue_Date=datetime.datetime(2017, 5, 17, 0, 0), Violation_Code=14, Vehicle_Body_Type='TRAC', Vehicle_Make='FRUEH', Violation_Description='14-No Standing')
# Ticket(Summons_Number=8530950458, Plate_ID='HAY5880', Registration_State='NY', Plate_Type='PAS', Issue_Date=datetime.datetime(2017, 4, 8, 0, 0), Violation_Code=14, Vehicle_Body_Type='SUBN', Vehicle_Make='GMC', Violation_Description='14-No Standing')
# Ticket(Summons_Number=8552003569, Plate_ID='XJ275S', Registration_State='NJ', Plate_Type='PAS', Issue_Date=datetime.datetime(2017, 4, 25, 0, 0), Violation_Code=14, Vehicle_Body_Type='PICK', Vehicle_Make='GMC', Violation_Description='14-No Standing')
# Ticket(Summons_Number=8536010903, Plate_ID='25472MG', Registration_State='NY', Plate_Type='COM', Issue_Date=datetime.datetime(2017, 6, 16, 0, 0), Violation_Code=14, Vehicle_Body_Type='REFG', Vehicle_Make='HIN', Violation_Description='14-No Standing')
# Ticket(Summons_Number=8508953549, Plate_ID='XDLS80', Registration_State='NJ', Plate_Type='PAS', Issue_Date=datetime.datetime(2017, 2, 1, 0, 0), Violation_Code=14, Vehicle_Body_Type='DELV', Vehicle_Make='HIN', Violation_Description='14-No Standing')
# Ticket(Summons_Number=7191990831, Plate_ID='AA00234', Registration_State='CT', Plate_Type='PAS', Issue_Date=datetime.datetime(2016, 7, 2, 0, 0), Violation_Code=14, Vehicle_Body_Type='SUBN', Vehicle_Make='HONDA', Violation_Description='14-No Standing')
# Ticket(Summons_Number=8519503676, Plate_ID='FCX7311', Registration_State='NY', Plate_Type='PAS', Issue_Date=datetime.datetime(2017, 3, 20, 0, 0), Violation_Code=14, Vehicle_Body_Type='SUBN', Vehicle_Make='HONDA', Violation_Description='14-No Standing')
# Ticket(Summons_Number=1418739704, Plate_ID='GJK5307', Registration_State='NY', Plate_Type='PAS', Issue_Date=datetime.datetime(2017, 4, 9, 0, 0), Violation_Code=14, Vehicle_Body_Type='SDN', Vehicle_Make='HONDA', Violation_Description='')
# Ticket(Summons_Number=7994359840, Plate_ID='GNG1097', Registration_State='TX', Plate_Type='PAS', Issue_Date=datetime.datetime(2016, 7, 15, 0, 0), Violation_Code=14, Vehicle_Body_Type='SUBN', Vehicle_Make='HONDA', Violation_Description='14-No Standing')
# Ticket(Summons_Number=1414856374, Plate_ID='HLE9929', Registration_State='NY', Plate_Type='PAS', Issue_Date=datetime.datetime(2017, 4, 13, 0, 0), Violation_Code=14, Vehicle_Body_Type='SUBN', Vehicle_Make='HONDA', Violation_Description='')
# Ticket(Summons_Number=8474909971, Plate_ID='S938464', Registration_State='IA', Plate_Type='PAS', Issue_Date=datetime.datetime(2017, 1, 9, 0, 0), Violation_Code=14, Vehicle_Body_Type='SUBN', Vehicle_Make='HONDA', Violation_Description='14-No Standing')
# Ticket(Summons_Number=1416903379, Plate_ID='CRM6911', Registration_State='NY', Plate_Type='PAS', Issue_Date=datetime.datetime(2016, 12, 16, 0, 0), Violation_Code=14, Vehicle_Body_Type='SDN', Vehicle_Make='HYUND', Violation_Description='')
# Ticket(Summons_Number=8340512559, Plate_ID='CZB9676', Registration_State='NY', Plate_Type='PAS', Issue_Date=datetime.datetime(2016, 8, 23, 0, 0), Violation_Code=14, Vehicle_Body_Type='2DSD', Vehicle_Make='HYUND', Violation_Description='14-No Standing')
# Ticket(Summons_Number=8497566683, Plate_ID='17596JE', Registration_State='NY', Plate_Type='COM', Issue_Date=datetime.datetime(2017, 6, 16, 0, 0), Violation_Code=14, Vehicle_Body_Type='DELV', Vehicle_Make='INTER', Violation_Description='14-No Standing')
# Ticket(Summons_Number=8517821075, Plate_ID='32295MA', Registration_State='NY', Plate_Type='COM', Issue_Date=datetime.datetime(2017, 6, 27, 0, 0), Violation_Code=14, Vehicle_Body_Type='DELV', Vehicle_Make='INTER', Violation_Description='14-No Standing')
# Ticket(Summons_Number=1418035762, Plate_ID='62935JM', Registration_State='NY', Plate_Type='COM', Issue_Date=datetime.datetime(2017, 1, 24, 0, 0), Violation_Code=14, Vehicle_Body_Type='DELV', Vehicle_Make='INTER', Violation_Description='')
# Ticket(Summons_Number=8482055392, Plate_ID='92638JU', Registration_State='NY', Plate_Type='COM', Issue_Date=datetime.datetime(2017, 1, 25, 0, 0), Violation_Code=14, Vehicle_Body_Type='VAN', Vehicle_Make='INTER', Violation_Description='14-No Standing')
# Ticket(Summons_Number=8506706490, Plate_ID='AP166T', Registration_State='NJ', Plate_Type='PAS', Issue_Date=datetime.datetime(2017, 2, 20, 0, 0), Violation_Code=14, Vehicle_Body_Type='DELV', Vehicle_Make='INTER', Violation_Description='14-No Standing')
# Ticket(Summons_Number=8473761297, Plate_ID='33049MJ', Registration_State='NY', Plate_Type='COM', Issue_Date=datetime.datetime(2017, 2, 1, 0, 0), Violation_Code=14, Vehicle_Body_Type='DELV', Vehicle_Make='ISUZU', Violation_Description='14-No Standing')
# Ticket(Summons_Number=8484877693, Plate_ID='XBYG52', Registration_State='NJ', Plate_Type='PAS', Issue_Date=datetime.datetime(2017, 5, 12, 0, 0), Violation_Code=14, Vehicle_Body_Type='VAN', Vehicle_Make='ISUZU', Violation_Description='14-No Standing')
# Ticket(Summons_Number=8152046917, Plate_ID='VFW9441', Registration_State='VA', Plate_Type='PAS', Issue_Date=datetime.datetime(2016, 8, 14, 0, 0), Violation_Code=14, Vehicle_Body_Type='SUBN', Vehicle_Make='JEEP', Violation_Description='14-No Standing')
# Ticket(Summons_Number=8503265503, Plate_ID='23800TC', Registration_State='NY', Plate_Type='TRC', Issue_Date=datetime.datetime(2017, 3, 28, 0, 0), Violation_Code=14, Vehicle_Body_Type='TRAC', Vehicle_Make='KENWO', Violation_Description='14-No Standing')
# Ticket(Summons_Number=8489721312, Plate_ID='49734MA', Registration_State='NY', Plate_Type='COM', Issue_Date=datetime.datetime(2017, 4, 4, 0, 0), Violation_Code=14, Vehicle_Body_Type='DELV', Vehicle_Make='KENWO', Violation_Description='14-No Standing')
# Ticket(Summons_Number=8464532088, Plate_ID='HJR5750', Registration_State='NY', Plate_Type='PAS', Issue_Date=datetime.datetime(2017, 2, 3, 0, 0), Violation_Code=14, Vehicle_Body_Type='SUBN', Vehicle_Make='KIA', Violation_Description='14-No Standing')
# Ticket(Summons_Number=8488825948, Plate_ID='HAU1278', Registration_State='NY', Plate_Type='PAS', Issue_Date=datetime.datetime(2017, 3, 31, 0, 0), Violation_Code=14, Vehicle_Body_Type='SUBN', Vehicle_Make='LEXUS', Violation_Description='14-No Standing')
# Ticket(Summons_Number=8559362496, Plate_ID='HLW7798', Registration_State='NY', Plate_Type='PAS', Issue_Date=datetime.datetime(2017, 6, 13, 0, 0), Violation_Code=14, Vehicle_Body_Type='4DSD', Vehicle_Make='LEXUS', Violation_Description='14-No Standing')
# Ticket(Summons_Number=8478353860, Plate_ID='VUE95C', Registration_State='NJ', Plate_Type='PAS', Issue_Date=datetime.datetime(2016, 12, 6, 0, 0), Violation_Code=14, Vehicle_Body_Type='4DSD', Vehicle_Make='LEXUS', Violation_Description='14-No Standing')
# Ticket(Summons_Number=8518911631, Plate_ID='ZD53LE', Registration_State='NJ', Plate_Type='PAS', Issue_Date=datetime.datetime(2017, 5, 17, 0, 0), Violation_Code=14, Vehicle_Body_Type='SUBN', Vehicle_Make='LEXUS', Violation_Description='14-No Standing')
# Ticket(Summons_Number=1416091415, Plate_ID='75213MH', Registration_State='NY', Plate_Type='COM', Issue_Date=datetime.datetime(2016, 11, 28, 0, 0), Violation_Code=14, Vehicle_Body_Type='VAN', Vehicle_Make='ME/BE', Violation_Description='')
# Ticket(Summons_Number=8482374059, Plate_ID='F96FBF', Registration_State='NJ', Plate_Type='PAS', Issue_Date=datetime.datetime(2017, 4, 23, 0, 0), Violation_Code=14, Vehicle_Body_Type='4DSD', Vehicle_Make='ME/BE', Violation_Description='14-No Standing')
# Ticket(Summons_Number=8544960947, Plate_ID='HMX8950', Registration_State='NY', Plate_Type='PAS', Issue_Date=datetime.datetime(2017, 5, 27, 0, 0), Violation_Code=14, Vehicle_Body_Type='4DSD', Vehicle_Make='ME/BE', Violation_Description='14-No Standing')
# Ticket(Summons_Number=1418609274, Plate_ID='8P82H', Registration_State='NY', Plate_Type='OMT', Issue_Date=datetime.datetime(2016, 12, 21, 0, 0), Violation_Code=14, Vehicle_Body_Type='TAXI', Vehicle_Make='NISSA', Violation_Description='')
# Ticket(Summons_Number=1417565895, Plate_ID='HEB8184', Registration_State='NY', Plate_Type='PAS', Issue_Date=datetime.datetime(2017, 2, 11, 0, 0), Violation_Code=14, Vehicle_Body_Type='SDN', Vehicle_Make='NISSA', Violation_Description='')
# Ticket(Summons_Number=8155550278, Plate_ID='W56GSE', Registration_State='NJ', Plate_Type='PAS', Issue_Date=datetime.datetime(2016, 10, 22, 0, 0), Violation_Code=14, Vehicle_Body_Type='4DSD', Vehicle_Make='NISSA', Violation_Description='14-No Standing')
# Ticket(Summons_Number=7433187960, Plate_ID='2330830', Registration_State='ME', Plate_Type='PAS', Issue_Date=datetime.datetime(2017, 3, 6, 0, 0), Violation_Code=14, Vehicle_Body_Type='TRLR', Vehicle_Make='NS/OT', Violation_Description='14-No Standing')
# Ticket(Summons_Number=7645052715, Plate_ID='FRZ3573', Registration_State='NY', Plate_Type='PAS', Issue_Date=datetime.datetime(2017, 1, 7, 0, 0), Violation_Code=14, Vehicle_Body_Type='SUBN', Vehicle_Make='NS/OT', Violation_Description='14-No Standing')
# Ticket(Summons_Number=7922559173, Plate_ID='XCYU94', Registration_State='NJ', Plate_Type='PAS', Issue_Date=datetime.datetime(2016, 10, 24, 0, 0), Violation_Code=14, Vehicle_Body_Type='VAN', Vehicle_Make='NS/OT', Violation_Description='14-No Standing')
# Ticket(Summons_Number=7767415582, Plate_ID='XW915N', Registration_State='NJ', Plate_Type='PAS', Issue_Date=datetime.datetime(2017, 3, 29, 0, 0), Violation_Code=14, Vehicle_Body_Type='DELV', Vehicle_Make='NS/OT', Violation_Description='14-No Standing')
# Ticket(Summons_Number=8524350581, Plate_ID='HGR5953', Registration_State='NY', Plate_Type='PAS', Issue_Date=datetime.datetime(2017, 2, 27, 0, 0), Violation_Code=14, Vehicle_Body_Type='4DSD', Vehicle_Make='OLDSM', Violation_Description='14-No Standing')
# Ticket(Summons_Number=7499844705, Plate_ID='GGT7948', Registration_State='NY', Plate_Type='PAS', Issue_Date=datetime.datetime(2016, 8, 22, 0, 0), Violation_Code=14, Vehicle_Body_Type='SUBN', Vehicle_Make='SUBAR', Violation_Description='14-No Standing')
# Ticket(Summons_Number=7150327266, Plate_ID='HWE6388', Registration_State='PA', Plate_Type='PAS', Issue_Date=datetime.datetime(2016, 8, 5, 0, 0), Violation_Code=14, Vehicle_Body_Type='SUBN', Vehicle_Make='SUBAR', Violation_Description='14-No Standing')
# Ticket(Summons_Number=8537603818, Plate_ID='ASG8770', Registration_State='NY', Plate_Type='PAS', Issue_Date=datetime.datetime(2017, 3, 26, 0, 0), Violation_Code=14, Vehicle_Body_Type='4DSD', Vehicle_Make='TOYOT', Violation_Description='14-No Standing')
# Ticket(Summons_Number=8210533952, Plate_ID='GST8679', Registration_State='NY', Plate_Type='PAS', Issue_Date=datetime.datetime(2016, 11, 21, 0, 0), Violation_Code=14, Vehicle_Body_Type='2DSD', Vehicle_Make='TOYOT', Violation_Description='14-No Standing')
# Ticket(Summons_Number=8555462198, Plate_ID='HKT4222', Registration_State='NY', Plate_Type='PAS', Issue_Date=datetime.datetime(2017, 6, 12, 0, 0), Violation_Code=14, Vehicle_Body_Type='SUBN', Vehicle_Make='TOYOT', Violation_Description='14-No Standing')
# Ticket(Summons_Number=1404838156, Plate_ID='R57AAE', Registration_State='NJ', Plate_Type='PAS', Issue_Date=datetime.datetime(2017, 4, 29, 0, 0), Violation_Code=14, Vehicle_Body_Type='SUBN', Vehicle_Make='TOYOT', Violation_Description='')
# Ticket(Summons_Number=8527806162, Plate_ID='T659832C', Registration_State='NY', Plate_Type='OMT', Issue_Date=datetime.datetime(2017, 6, 4, 0, 0), Violation_Code=14, Vehicle_Body_Type='4DSD', Vehicle_Make='TOYOT', Violation_Description='14-No Standing')
# Ticket(Summons_Number=8513520615, Plate_ID='77026MG', Registration_State='NY', Plate_Type='COM', Issue_Date=datetime.datetime(2017, 5, 31, 0, 0), Violation_Code=14, Vehicle_Body_Type='TRAC', Vehicle_Make='VOLVO', Violation_Description='14-No Standing')
# Ticket(Summons_Number=8251031485, Plate_ID='HJP5565', Registration_State='NY', Plate_Type='PAS', Issue_Date=datetime.datetime(2016, 10, 4, 0, 0), Violation_Code=16, Vehicle_Body_Type='4DSD', Vehicle_Make='CHEVR', Violation_Description='16A-No Std (Com Veh) Non-COM')
# Ticket(Summons_Number=7813745231, Plate_ID='GEL1890', Registration_State='NY', Plate_Type='PAS', Issue_Date=datetime.datetime(2016, 9, 19, 0, 0), Violation_Code=16, Vehicle_Body_Type='SUBN', Vehicle_Make='CHRYS', Violation_Description='16A-No Std (Com Veh) Non-COM')
# Ticket(Summons_Number=8444534183, Plate_ID='36598MH', Registration_State='NY', Plate_Type='COM', Issue_Date=datetime.datetime(2016, 11, 23, 0, 0), Violation_Code=16, Vehicle_Body_Type='VAN', Vehicle_Make='DODGE', Violation_Description='16-No Std (Com Veh) Com Plate')
# Ticket(Summons_Number=8061037749, Plate_ID='HFG7121', Registration_State='NY', Plate_Type='PAS', Issue_Date=datetime.datetime(2016, 8, 22, 0, 0), Violation_Code=16, Vehicle_Body_Type='SUBN', Vehicle_Make='DODGE', Violation_Description='16A-No Std (Com Veh) Non-COM')
# Ticket(Summons_Number=8250539527, Plate_ID='24745ME', Registration_State='NY', Plate_Type='COM', Issue_Date=datetime.datetime(2016, 11, 9, 0, 0), Violation_Code=16, Vehicle_Body_Type='VAN', Vehicle_Make='FORD', Violation_Description='16-No Std (Com Veh) Com Plate')
# Ticket(Summons_Number=8308520170, Plate_ID='49033ME', Registration_State='NY', Plate_Type='COM', Issue_Date=datetime.datetime(2016, 7, 14, 0, 0), Violation_Code=16, Vehicle_Body_Type='VAN', Vehicle_Make='FORD', Violation_Description='16-No Std (Com Veh) Com Plate')
# Ticket(Summons_Number=8504915323, Plate_ID='57011ME', Registration_State='NY', Plate_Type='COM', Issue_Date=datetime.datetime(2017, 4, 6, 0, 0), Violation_Code=16, Vehicle_Body_Type='SUBN', Vehicle_Make='FORD', Violation_Description='16-No Std (Com Veh) Com Plate')
# Ticket(Summons_Number=8339536023, Plate_ID='XCEG93', Registration_State='NJ', Plate_Type='PAS', Issue_Date=datetime.datetime(2016, 9, 15, 0, 0), Violation_Code=16, Vehicle_Body_Type='VAN', Vehicle_Make='FORD', Violation_Description='16-No Std (Com Veh) Com Plate')
# Ticket(Summons_Number=8566405183, Plate_ID='GJD5585', Registration_State='NY', Plate_Type='PAS', Issue_Date=datetime.datetime(2017, 6, 1, 0, 0), Violation_Code=16, Vehicle_Body_Type='4DSD', Vehicle_Make='ME/BE', Violation_Description='16A-No Std (Com Veh) Non-COM')
# Ticket(Summons_Number=7051225662, Plate_ID='N61GZN', Registration_State='NJ', Plate_Type='PAS', Issue_Date=datetime.datetime(2016, 11, 25, 0, 0), Violation_Code=16, Vehicle_Body_Type='SUBN', Vehicle_Make='SATUR', Violation_Description='16A-No Std (Com Veh) Non-COM')
# Ticket(Summons_Number=8149510126, Plate_ID='GTP8988', Registration_State='NY', Plate_Type='PAS', Issue_Date=datetime.datetime(2016, 8, 10, 0, 0), Violation_Code=16, Vehicle_Body_Type='2DSD', Vehicle_Make='SMART', Violation_Description='16A-No Std (Com Veh) Non-COM')
# Ticket(Summons_Number=7052028463, Plate_ID='HGM9782', Registration_State='NY', Plate_Type='PAS', Issue_Date=datetime.datetime(2017, 1, 30, 0, 0), Violation_Code=16, Vehicle_Body_Type='SUBN', Vehicle_Make='TOYOT', Violation_Description='16A-No Std (Com Veh) Non-COM')
# Ticket(Summons_Number=8474913706, Plate_ID='T674455C', Registration_State='NY', Plate_Type='OMT', Issue_Date=datetime.datetime(2017, 2, 8, 0, 0), Violation_Code=16, Vehicle_Body_Type='4DSD', Vehicle_Make='TOYOT', Violation_Description='16A-No Std (Com Veh) Non-COM')
# Ticket(Summons_Number=8506607206, Plate_ID='18752MH', Registration_State='NY', Plate_Type='COM', Issue_Date=datetime.datetime(2017, 3, 16, 0, 0), Violation_Code=17, Vehicle_Body_Type='VAN', Vehicle_Make='CHEVR', Violation_Description='17-No Stand (exc auth veh)')
# Ticket(Summons_Number=8438519763, Plate_ID='89882JV', Registration_State='NY', Plate_Type='COM', Issue_Date=datetime.datetime(2016, 10, 13, 0, 0), Violation_Code=17, Vehicle_Body_Type='VAN', Vehicle_Make='GMC', Violation_Description='17-No Stand (exc auth veh)')
# Ticket(Summons_Number=8551111954, Plate_ID='GCE9214', Registration_State='NY', Plate_Type='PAS', Issue_Date=datetime.datetime(2017, 6, 25, 0, 0), Violation_Code=17, Vehicle_Body_Type='4DSD', Vehicle_Make='HONDA', Violation_Description='17-No Stand (exc auth veh)')
# Ticket(Summons_Number=8516654059, Plate_ID='AP169V', Registration_State='NJ', Plate_Type='PAS', Issue_Date=datetime.datetime(2017, 2, 22, 0, 0), Violation_Code=18, Vehicle_Body_Type='DELV', Vehicle_Make='INTER', Violation_Description='18-No Stand (bus lane)')
# Ticket(Summons_Number=1368119141, Plate_ID='BMLV150', Registration_State='ON', Plate_Type='PAS', Issue_Date=datetime.datetime(2016, 7, 16, 0, 0), Violation_Code=19, Vehicle_Body_Type='SUBN', Vehicle_Make='CHEVR', Violation_Description='')
# Ticket(Summons_Number=8528274184, Plate_ID='EKF9820', Registration_State='NY', Plate_Type='PAS', Issue_Date=datetime.datetime(2017, 5, 1, 0, 0), Violation_Code=19, Vehicle_Body_Type='SUBN', Vehicle_Make='CHEVR', Violation_Description='19-No Stand (bus stop)')
# Ticket(Summons_Number=8522350073, Plate_ID='83290MD', Registration_State='NY', Plate_Type='COM', Issue_Date=datetime.datetime(2017, 2, 24, 0, 0), Violation_Code=19, Vehicle_Body_Type='SUBN', Vehicle_Make='DODGE', Violation_Description='19-No Stand (bus stop)')
# Ticket(Summons_Number=8070097437, Plate_ID='T62GJP', Registration_State='NJ', Plate_Type='PAS', Issue_Date=datetime.datetime(2016, 9, 18, 0, 0), Violation_Code=19, Vehicle_Body_Type='PICK', Vehicle_Make='DODGE', Violation_Description='19-No Stand (bus stop)')
# Ticket(Summons_Number=8509409523, Plate_ID='35050JU', Registration_State='NY', Plate_Type='COM', Issue_Date=datetime.datetime(2017, 2, 24, 0, 0), Violation_Code=19, Vehicle_Body_Type='PICK', Vehicle_Make='FORD', Violation_Description='19-No Stand (bus stop)')
# Ticket(Summons_Number=1413553552, Plate_ID='41126BB', Registration_State='NY', Plate_Type='OMT', Issue_Date=datetime.datetime(2016, 7, 28, 0, 0), Violation_Code=19, Vehicle_Body_Type='VAN', Vehicle_Make='FORD', Violation_Description='')
# Ticket(Summons_Number=8514220482, Plate_ID='2588073', Registration_State='IN', Plate_Type='PAS', Issue_Date=datetime.datetime(2017, 5, 29, 0, 0), Violation_Code=19, Vehicle_Body_Type='DELV', Vehicle_Make='FRUEH', Violation_Description='19-No Stand (bus stop)')
# Ticket(Summons_Number=8485652319, Plate_ID='0480PRA', Registration_State='MN', Plate_Type='PAS', Issue_Date=datetime.datetime(2017, 1, 26, 0, 0), Violation_Code=19, Vehicle_Body_Type='DELV', Vehicle_Make='FRUEH', Violation_Description='19-No Stand (bus stop)')
# Ticket(Summons_Number=7014671406, Plate_ID='B0951V', Registration_State='FL', Plate_Type='PAS', Issue_Date=datetime.datetime(2016, 9, 7, 0, 0), Violation_Code=19, Vehicle_Body_Type='DELV', Vehicle_Make='FRUEH', Violation_Description='19-No Stand (bus stop)')
# Ticket(Summons_Number=1422732710, Plate_ID='GMK4592', Registration_State='NY', Plate_Type='PAS', Issue_Date=datetime.datetime(2017, 6, 19, 0, 0), Violation_Code=19, Vehicle_Body_Type='SDN', Vehicle_Make='HONDA', Violation_Description='')
# Ticket(Summons_Number=7249114220, Plate_ID='GPP7413', Registration_State='NY', Plate_Type='PAS', Issue_Date=datetime.datetime(2016, 10, 8, 0, 0), Violation_Code=19, Vehicle_Body_Type='SUBN', Vehicle_Make='HONDA', Violation_Description='19-No Stand (bus stop)')
# Ticket(Summons_Number=7499990163, Plate_ID='HKT3209', Registration_State='NY', Plate_Type='PAS', Issue_Date=datetime.datetime(2016, 12, 13, 0, 0), Violation_Code=19, Vehicle_Body_Type='SUBN', Vehicle_Make='HONDA', Violation_Description='19-No Stand (bus stop)')
# Ticket(Summons_Number=8491667738, Plate_ID='JPC4516', Registration_State='PA', Plate_Type='PAS', Issue_Date=datetime.datetime(2017, 3, 1, 0, 0), Violation_Code=19, Vehicle_Body_Type='4DSD', Vehicle_Make='INFIN', Violation_Description='19-No Stand (bus stop)')
# Ticket(Summons_Number=8302046280, Plate_ID='63444JM', Registration_State='NY', Plate_Type='COM', Issue_Date=datetime.datetime(2017, 1, 26, 0, 0), Violation_Code=19, Vehicle_Body_Type='VAN', Vehicle_Make='INTER', Violation_Description='19-No Stand (bus stop)')
# Ticket(Summons_Number=8009901763, Plate_ID='13657MD', Registration_State='NY', Plate_Type='COM', Issue_Date=datetime.datetime(2016, 9, 27, 0, 0), Violation_Code=19, Vehicle_Body_Type='DELV', Vehicle_Make='KENWO', Violation_Description='19-No Stand (bus stop)')
# Ticket(Summons_Number=1424024420, Plate_ID='HPD1970', Registration_State='NY', Plate_Type='PAS', Issue_Date=datetime.datetime(2017, 6, 10, 0, 0), Violation_Code=19, Vehicle_Body_Type='SDN', Vehicle_Make='KIA', Violation_Description='')
# Ticket(Summons_Number=8511718990, Plate_ID='50104MH', Registration_State='NY', Plate_Type='COM', Issue_Date=datetime.datetime(2017, 6, 9, 0, 0), Violation_Code=19, Vehicle_Body_Type='VAN', Vehicle_Make='ME/BE', Violation_Description='19-No Stand (bus stop)')
# Ticket(Summons_Number=1415429522, Plate_ID='17236MH', Registration_State='NY', Plate_Type='COM', Issue_Date=datetime.datetime(2017, 3, 3, 0, 0), Violation_Code=19, Vehicle_Body_Type='SUBN', Vehicle_Make='MITSU', Violation_Description='')
# Ticket(Summons_Number=8476355312, Plate_ID='47829MD', Registration_State='NY', Plate_Type='COM', Issue_Date=datetime.datetime(2017, 2, 14, 0, 0), Violation_Code=19, Vehicle_Body_Type='DELV', Vehicle_Make='PETER', Violation_Description='19-No Stand (bus stop)')
# Ticket(Summons_Number=1406918726, Plate_ID='5M39B', Registration_State='NY', Plate_Type='OMT', Issue_Date=datetime.datetime(2016, 7, 13, 0, 0), Violation_Code=19, Vehicle_Body_Type='TAXI', Vehicle_Make='TOYOT', Violation_Description='')
# Ticket(Summons_Number=7241990262, Plate_ID='DVA1919', Registration_State='NY', Plate_Type='PAS', Issue_Date=datetime.datetime(2016, 11, 16, 0, 0), Violation_Code=19, Vehicle_Body_Type='SUBN', Vehicle_Make='TOYOT', Violation_Description='19-No Stand (bus stop)')
# Ticket(Summons_Number=8330511935, Plate_ID='HBY7509', Registration_State='NY', Plate_Type='PAS', Issue_Date=datetime.datetime(2016, 7, 30, 0, 0), Violation_Code=19, Vehicle_Body_Type='4DSD', Vehicle_Make='TOYOT', Violation_Description='19-No Stand (bus stop)')
# Ticket(Summons_Number=1423536058, Plate_ID='HCS2336', Registration_State='NY', Plate_Type='PAS', Issue_Date=datetime.datetime(2017, 1, 27, 0, 0), Violation_Code=19, Vehicle_Body_Type='SUBN', Vehicle_Make='TOYOT', Violation_Description='')
# Ticket(Summons_Number=8519016595, Plate_ID='QU655', Registration_State='RI', Plate_Type='PAS', Issue_Date=datetime.datetime(2017, 6, 12, 0, 0), Violation_Code=19, Vehicle_Body_Type='4DSD', Vehicle_Make='TOYOT', Violation_Description='19-No Stand (bus stop)')
# ...
# Ticket(Summons_Number=8263642668, Plate_ID='HEA6308', Registration_State='NY', Plate_Type='PAS', Issue_Date=datetime.datetime(2017, 2, 16, 0, 0), Violation_Code=71, Vehicle_Body_Type='SUBN', Vehicle_Make='JEEP', Violation_Description='71A-Insp Sticker Expired (NYS)')
# Ticket(Summons_Number=7067047705, Plate_ID='HFF1432', Registration_State='NY', Plate_Type='PAS', Issue_Date=datetime.datetime(2016, 9, 23, 0, 0), Violation_Code=71, Vehicle_Body_Type='SUBN', Vehicle_Make='JEEP', Violation_Description='71A-Insp Sticker Expired (NYS)')
# Ticket(Summons_Number=8168032202, Plate_ID='GZN5776', Registration_State='NY', Plate_Type='PAS', Issue_Date=datetime.datetime(2016, 8, 3, 0, 0), Violation_Code=71, Vehicle_Body_Type='4DSD', Vehicle_Make='LEXUS', Violation_Description='71A-Insp Sticker Expired (NYS)')
# Ticket(Summons_Number=8507861787, Plate_ID='HMY3697', Registration_State='NY', Plate_Type='PAS', Issue_Date=datetime.datetime(2017, 4, 10, 0, 0), Violation_Code=71, Vehicle_Body_Type='SUBN', Vehicle_Make='LEXUS', Violation_Description='71A-Insp Sticker Expired (NYS)')
# Ticket(Summons_Number=8297047957, Plate_ID='GUV7315', Registration_State='NY', Plate_Type='PAS', Issue_Date=datetime.datetime(2016, 12, 3, 0, 0), Violation_Code=71, Vehicle_Body_Type='4DSD', Vehicle_Make='LINCO', Violation_Description='71A-Insp Sticker Expired (NYS)')
# Ticket(Summons_Number=8472853342, Plate_ID='HJN6543', Registration_State='NY', Plate_Type='PAS', Issue_Date=datetime.datetime(2016, 10, 4, 0, 0), Violation_Code=71, Vehicle_Body_Type='2DSD', Vehicle_Make='LINCO', Violation_Description='71A-Insp Sticker Expired (NYS)')
# Ticket(Summons_Number=8524860388, Plate_ID='HGR2303', Registration_State='NY', Plate_Type='PAS', Issue_Date=datetime.datetime(2017, 4, 10, 0, 0), Violation_Code=71, Vehicle_Body_Type='CONV', Vehicle_Make='ME/BE', Violation_Description='71A-Insp Sticker Expired (NYS)')
# Ticket(Summons_Number=8561753377, Plate_ID='GWY8527', Registration_State='NY', Plate_Type='PAS', Issue_Date=datetime.datetime(2017, 5, 26, 0, 0), Violation_Code=71, Vehicle_Body_Type='SUBN', Vehicle_Make='MERCU', Violation_Description='71A-Insp Sticker Expired (NYS)')
# Ticket(Summons_Number=8544876754, Plate_ID='GBE4270', Registration_State='NY', Plate_Type='PAS', Issue_Date=datetime.datetime(2017, 5, 24, 0, 0), Violation_Code=71, Vehicle_Body_Type='4DSD', Vehicle_Make='NISSA', Violation_Description='71A-Insp Sticker Expired (NYS)')
# Ticket(Summons_Number=7803960030, Plate_ID='HBU4265', Registration_State='NY', Plate_Type='PAS', Issue_Date=datetime.datetime(2017, 1, 7, 0, 0), Violation_Code=71, Vehicle_Body_Type='4DSD', Vehicle_Make='NISSA', Violation_Description='71A-Insp Sticker Expired (NYS)')
# Ticket(Summons_Number=7492597289, Plate_ID='HDF5609', Registration_State='NY', Plate_Type='PAS', Issue_Date=datetime.datetime(2016, 8, 19, 0, 0), Violation_Code=71, Vehicle_Body_Type='4DSD', Vehicle_Make='NISSA', Violation_Description='71A-Insp Sticker Expired (NYS)')
# Ticket(Summons_Number=8400523477, Plate_ID='HKT1200', Registration_State='NY', Plate_Type='PAS', Issue_Date=datetime.datetime(2016, 11, 28, 0, 0), Violation_Code=71, Vehicle_Body_Type='4DSD', Vehicle_Make='NISSA', Violation_Description='71-Insp. Sticker Missing (NYS')
# Ticket(Summons_Number=7646792536, Plate_ID='T686872C', Registration_State='NY', Plate_Type='OMT', Issue_Date=datetime.datetime(2016, 9, 14, 0, 0), Violation_Code=71, Vehicle_Body_Type='4DSD', Vehicle_Make='NISSA', Violation_Description='71A-Insp Sticker Expired (NYS)')
# Ticket(Summons_Number=8208026335, Plate_ID='DHW7141', Registration_State='NY', Plate_Type='PAS', Issue_Date=datetime.datetime(2016, 8, 5, 0, 0), Violation_Code=71, Vehicle_Body_Type='2DSD', Vehicle_Make='NS/OT', Violation_Description='71A-Insp Sticker Expired (NYS)')
# Ticket(Summons_Number=7959796476, Plate_ID='GPY8489', Registration_State='NY', Plate_Type='PAS', Issue_Date=datetime.datetime(2016, 10, 6, 0, 0), Violation_Code=71, Vehicle_Body_Type='SUBN', Vehicle_Make='ROVER', Violation_Description='71A-Insp Sticker Expired (NYS)')
# Ticket(Summons_Number=8509455028, Plate_ID='34632BB', Registration_State='NY', Plate_Type='OMR', Issue_Date=datetime.datetime(2017, 2, 12, 0, 0), Violation_Code=71, Vehicle_Body_Type='BUS', Vehicle_Make='STAR', Violation_Description='71A-Insp Sticker Expired (NYS)')
# Ticket(Summons_Number=8393022400, Plate_ID='HFP5696', Registration_State='NY', Plate_Type='PAS', Issue_Date=datetime.datetime(2016, 11, 16, 0, 0), Violation_Code=71, Vehicle_Body_Type='SUBN', Vehicle_Make='SUBAR', Violation_Description='71A-Insp Sticker Expired (NYS)')
# Ticket(Summons_Number=8525217207, Plate_ID='HGM9849', Registration_State='NY', Plate_Type='PAS', Issue_Date=datetime.datetime(2017, 5, 3, 0, 0), Violation_Code=71, Vehicle_Body_Type='SUBN', Vehicle_Make='SUBAR', Violation_Description='71A-Insp Sticker Expired (NYS)')
# Ticket(Summons_Number=8562558047, Plate_ID='CWP4893', Registration_State='NY', Plate_Type='PAS', Issue_Date=datetime.datetime(2017, 6, 1, 0, 0), Violation_Code=71, Vehicle_Body_Type='SUBN', Vehicle_Make='TOYOT', Violation_Description='71A-Insp Sticker Expired (NYS)')
# Ticket(Summons_Number=8236037095, Plate_ID='GMR8112', Registration_State='NY', Plate_Type='PAS', Issue_Date=datetime.datetime(2016, 9, 17, 0, 0), Violation_Code=71, Vehicle_Body_Type='2DSD', Vehicle_Make='TOYOT', Violation_Description='71A-Insp Sticker Expired (NYS)')
# Ticket(Summons_Number=8514463690, Plate_ID='GMZ9712', Registration_State='NY', Plate_Type='PAS', Issue_Date=datetime.datetime(2017, 3, 30, 0, 0), Violation_Code=71, Vehicle_Body_Type='4DSD', Vehicle_Make='TOYOT', Violation_Description='71A-Insp Sticker Expired (NYS)')
# Ticket(Summons_Number=8358550790, Plate_ID='HDY4158', Registration_State='NY', Plate_Type='PAS', Issue_Date=datetime.datetime(2017, 2, 18, 0, 0), Violation_Code=71, Vehicle_Body_Type='4DSD', Vehicle_Make='TOYOT', Violation_Description='71A-Insp Sticker Expired (NYS)')
# Ticket(Summons_Number=7959486440, Plate_ID='GYF2052', Registration_State='NY', Plate_Type='PAS', Issue_Date=datetime.datetime(2016, 7, 7, 0, 0), Violation_Code=71, Vehicle_Body_Type='4DSD', Vehicle_Make='VOLKS', Violation_Description='71-Insp. Sticker Missing (NYS')
# Ticket(Summons_Number=8300538318, Plate_ID='HFR6545', Registration_State='NY', Plate_Type='PAS', Issue_Date=datetime.datetime(2016, 10, 31, 0, 0), Violation_Code=71, Vehicle_Body_Type='4DSD', Vehicle_Make='VOLVO', Violation_Description='71-Insp. Sticker Missing (NYS')
# Ticket(Summons_Number=8523013120, Plate_ID='HPN9774', Registration_State='NY', Plate_Type='PAS', Issue_Date=datetime.datetime(2017, 4, 6, 0, 0), Violation_Code=74, Vehicle_Body_Type='4DSD', Vehicle_Make='CHEVR', Violation_Description='74-Missing Display Plate')
# Ticket(Summons_Number=7008336767, Plate_ID='HWL4734', Registration_State='PA', Plate_Type='PAS', Issue_Date=datetime.datetime(2017, 1, 14, 0, 0), Violation_Code=74, Vehicle_Body_Type='4DSD', Vehicle_Make='CHEVR', Violation_Description='74A-Improperly Displayed Plate')
# Ticket(Summons_Number=8397514636, Plate_ID='FYW3850', Registration_State='NY', Plate_Type='PAS', Issue_Date=datetime.datetime(2016, 10, 22, 0, 0), Violation_Code=74, Vehicle_Body_Type='SUBN', Vehicle_Make='FORD', Violation_Description='74A-Improperly Displayed Plate')
# Ticket(Summons_Number=8528912840, Plate_ID='HNY5206', Registration_State='NY', Plate_Type='PAS', Issue_Date=datetime.datetime(2017, 4, 21, 0, 0), Violation_Code=74, Vehicle_Body_Type='SUBN', Vehicle_Make='GMC', Violation_Description='74A-Improperly Displayed Plate')
# Ticket(Summons_Number=8511501113, Plate_ID='FBP6836', Registration_State='NY', Plate_Type='PAS', Issue_Date=datetime.datetime(2017, 2, 16, 0, 0), Violation_Code=74, Vehicle_Body_Type='SUBN', Vehicle_Make='HONDA', Violation_Description='74-Missing Display Plate')
# Ticket(Summons_Number=8276551890, Plate_ID='HJR4081', Registration_State='NY', Plate_Type='PAS', Issue_Date=datetime.datetime(2017, 1, 7, 0, 0), Violation_Code=74, Vehicle_Body_Type='SUBN', Vehicle_Make='HONDA', Violation_Description='74A-Improperly Displayed Plate')
# Ticket(Summons_Number=8214550531, Plate_ID='HJY2207', Registration_State='NY', Plate_Type='PAS', Issue_Date=datetime.datetime(2017, 3, 9, 0, 0), Violation_Code=74, Vehicle_Body_Type='4DSD', Vehicle_Make='HYUND', Violation_Description='74-Missing Display Plate')
# Ticket(Summons_Number=8487469012, Plate_ID='27527ME', Registration_State='NY', Plate_Type='COM', Issue_Date=datetime.datetime(2017, 1, 27, 0, 0), Violation_Code=74, Vehicle_Body_Type='DELV', Vehicle_Make='INTER', Violation_Description='74-Missing Display Plate')
# Ticket(Summons_Number=8034780236, Plate_ID='HCD3158', Registration_State='NY', Plate_Type='PAS', Issue_Date=datetime.datetime(2016, 9, 2, 0, 0), Violation_Code=74, Vehicle_Body_Type='SUBN', Vehicle_Make='KIA', Violation_Description='74A-Improperly Displayed Plate')
# Ticket(Summons_Number=8545052455, Plate_ID='HMK1149', Registration_State='NY', Plate_Type='PAS', Issue_Date=datetime.datetime(2017, 6, 7, 0, 0), Violation_Code=74, Vehicle_Body_Type='4DSD', Vehicle_Make='ME/BE', Violation_Description='74-Missing Display Plate')
# Ticket(Summons_Number=1411263467, Plate_ID='BLANKPLATE', Registration_State='99', Plate_Type='999', Issue_Date=datetime.datetime(2017, 2, 13, 0, 0), Violation_Code=74, Vehicle_Body_Type='SDN', Vehicle_Make='NISSA', Violation_Description='')
# Ticket(Summons_Number=8540001550, Plate_ID='HLA4803', Registration_State='NY', Plate_Type='PAS', Issue_Date=datetime.datetime(2017, 3, 23, 0, 0), Violation_Code=74, Vehicle_Body_Type='4DSD', Vehicle_Make='SAAB', Violation_Description='74-Missing Display Plate')
# Ticket(Summons_Number=8556155431, Plate_ID='HFB9919', Registration_State='NY', Plate_Type='PAS', Issue_Date=datetime.datetime(2017, 5, 26, 0, 0), Violation_Code=75, Vehicle_Body_Type='4DSD', Vehicle_Make='DODGE', Violation_Description='75-No Match-Plate/Reg. Sticker')
# Ticket(Summons_Number=8394016790, Plate_ID='31690BB', Registration_State='NY', Plate_Type='OMR', Issue_Date=datetime.datetime(2016, 9, 6, 0, 0), Violation_Code=77, Vehicle_Body_Type='BUS', Vehicle_Make='AM/T', Violation_Description='77-Parked Bus (exc desig area)')
# Ticket(Summons_Number=1419472306, Plate_ID='56090BA', Registration_State='NY', Plate_Type='OMR', Issue_Date=datetime.datetime(2017, 2, 20, 0, 0), Violation_Code=77, Vehicle_Body_Type='BUS', Vehicle_Make='INTER', Violation_Description='')
# Ticket(Summons_Number=8363508688, Plate_ID='97256', Registration_State='MA', Plate_Type='APP', Issue_Date=datetime.datetime(2016, 8, 13, 0, 0), Violation_Code=77, Vehicle_Body_Type='BUS', Vehicle_Make='NS/OT', Violation_Description='77-Parked Bus (exc desig area)')
# Ticket(Summons_Number=1407740258, Plate_ID='2513JMG', Registration_State='NY', Plate_Type='COM', Issue_Date=datetime.datetime(2017, 1, 11, 0, 0), Violation_Code=78, Vehicle_Body_Type='DELV', Vehicle_Make='FRUEH', Violation_Description='')
# Ticket(Summons_Number=8081047670, Plate_ID='AG84195', Registration_State='AZ', Plate_Type='PAS', Issue_Date=datetime.datetime(2016, 9, 1, 0, 0), Violation_Code=78, Vehicle_Body_Type='DELV', Vehicle_Make='GMC', Violation_Description='78-Nighttime PKG on Res Street')
# Ticket(Summons_Number=8357010039, Plate_ID='ZBK5659', Registration_State='PA', Plate_Type='PAS', Issue_Date=datetime.datetime(2016, 9, 16, 0, 0), Violation_Code=78, Vehicle_Body_Type='FLAT', Vehicle_Make='NS/OT', Violation_Description='78-Nighttime PKG on Res Street')
# Ticket(Summons_Number=1408164401, Plate_ID='GCP8663', Registration_State='NY', Plate_Type='PAS', Issue_Date=datetime.datetime(2016, 9, 30, 0, 0), Violation_Code=80, Vehicle_Body_Type='SUBN', Vehicle_Make='CHEVR', Violation_Description='')
# Ticket(Summons_Number=7065087220, Plate_ID='35989MJ', Registration_State='NY', Plate_Type='COM', Issue_Date=datetime.datetime(2016, 8, 28, 0, 0), Violation_Code=82, Vehicle_Body_Type='VAN', Vehicle_Make='CHEVR', Violation_Description='82-Unaltered Commerc Vehicle')
# Ticket(Summons_Number=8472028628, Plate_ID='80921MH', Registration_State='NY', Plate_Type='COM', Issue_Date=datetime.datetime(2017, 1, 30, 0, 0), Violation_Code=82, Vehicle_Body_Type='VAN', Vehicle_Make='CHEVR', Violation_Description='82-Unaltered Commerc Vehicle')
# Ticket(Summons_Number=8413507250, Plate_ID='XCGT11', Registration_State='NJ', Plate_Type='PAS', Issue_Date=datetime.datetime(2016, 10, 18, 0, 0), Violation_Code=82, Vehicle_Body_Type='PICK', Vehicle_Make='CHEVR', Violation_Description='82-Unaltered Commerc Vehicle')
# Ticket(Summons_Number=8498413898, Plate_ID='2028133', Registration_State='IN', Plate_Type='PAS', Issue_Date=datetime.datetime(2017, 5, 24, 0, 0), Violation_Code=84, Vehicle_Body_Type='DELV', Vehicle_Make='FRUEH', Violation_Description='84-Platform lifts in low posit')
# Ticket(Summons_Number=8484405837, Plate_ID='2028134', Registration_State='IN', Plate_Type='PAS', Issue_Date=datetime.datetime(2017, 2, 15, 0, 0), Violation_Code=84, Vehicle_Body_Type='DELV', Vehicle_Make='FRUEH', Violation_Description='84-Platform lifts in low posit')
# Ticket(Summons_Number=8040125108, Plate_ID='AT985A', Registration_State='NJ', Plate_Type='PAS', Issue_Date=datetime.datetime(2016, 8, 29, 0, 0), Violation_Code=84, Vehicle_Body_Type='DELV', Vehicle_Make='FRUEH', Violation_Description='84-Platform lifts in low posit')
# Ticket(Summons_Number=8521821979, Plate_ID='XJX4470', Registration_State='PA', Plate_Type='PAS', Issue_Date=datetime.datetime(2017, 5, 18, 0, 0), Violation_Code=84, Vehicle_Body_Type='TR/C', Vehicle_Make='FRUEH', Violation_Description='84-Platform lifts in low posit')
# Ticket(Summons_Number=7662741072, Plate_ID='XY237D', Registration_State='NJ', Plate_Type='PAS', Issue_Date=datetime.datetime(2016, 8, 9, 0, 0), Violation_Code=84, Vehicle_Body_Type='DELV', Vehicle_Make='HINO', Violation_Description='84-Platform lifts in low posit')
# Ticket(Summons_Number=8529157072, Plate_ID='2380604', Registration_State='IN', Plate_Type='PAS', Issue_Date=datetime.datetime(2017, 3, 29, 0, 0), Violation_Code=84, Vehicle_Body_Type='DELV', Vehicle_Make='INTER', Violation_Description='84-Platform lifts in low posit')
# Ticket(Summons_Number=8354508808, Plate_ID='21239MG', Registration_State='NY', Plate_Type='COM', Issue_Date=datetime.datetime(2016, 9, 9, 0, 0), Violation_Code=84, Vehicle_Body_Type='DELV', Vehicle_Make='MI/F', Violation_Description='84-Platform lifts in low posit')
# Ticket(Summons_Number=1414702700, Plate_ID='AT785J', Registration_State='NJ', Plate_Type='PAS', Issue_Date=datetime.datetime(2016, 11, 27, 0, 0), Violation_Code=85, Vehicle_Body_Type='TRAC', Vehicle_Make='FRUEH', Violation_Description='')
# Ticket(Summons_Number=8466533837, Plate_ID='XANK50', Registration_State='NJ', Plate_Type='PAS', Issue_Date=datetime.datetime(2017, 4, 29, 0, 0), Violation_Code=85, Vehicle_Body_Type='DELV', Vehicle_Make='HIN', Violation_Description='85-Storage-3 hour Commercial')
# Ticket(Summons_Number=8525168063, Plate_ID='HBN8474', Registration_State='NY', Plate_Type='PAS', Issue_Date=datetime.datetime(2017, 5, 30, 0, 0), Violation_Code=91, Vehicle_Body_Type='SUBN', Vehicle_Make='HONDA', Violation_Description='91-Veh for Sale (Dealer Only)')
# Ticket(Summons_Number=1420730010, Plate_ID='GFW3620', Registration_State='NY', Plate_Type='PAS', Issue_Date=datetime.datetime(2017, 6, 10, 0, 0), Violation_Code=98, Vehicle_Body_Type='SUBN', Vehicle_Make='CHEVR', Violation_Description='')
# Ticket(Summons_Number=1414049870, Plate_ID='EJS4309', Registration_State='NY', Plate_Type='PAS', Issue_Date=datetime.datetime(2016, 8, 5, 0, 0), Violation_Code=98, Vehicle_Body_Type='SDN', Vehicle_Make='NISSA', Violation_Description='')
# Ticket(Summons_Number=1420795430, Plate_ID='HBS5720', Registration_State='NY', Plate_Type='PAS', Issue_Date=datetime.datetime(2017, 4, 18, 0, 0), Violation_Code=98, Vehicle_Body_Type='SDN', Vehicle_Make='NISSA', Violation_Description='')

# %% [markdown]
# # Goal 2

# %% [markdown]
# ### Calculate the number of violations by car make.

# %%
violations = defaultdict(int)
for ticket in get_tickets():
     violations[ticket.Vehicle_Make] += 1

{print(key,value,end="\n") for (key,value) in violations.items()}
# Out:
# BMW 34
# CHEVR 76
# DODGE 45
# FORD 104
# FRUEH 44
# HONDA 106
# LINCO 12
# TOYOT 112
# CADIL 9
# CHRYS 12
# FIR 1
# GMC 35
# HYUND 35
# JAGUA 3
# JEEP 22
# LEXUS 26
# ME/BE 38
# MERCU 4
# MITSU 11
# NISSA 70
# HIN 6
# NS/OT 18
# WORKH 2
# ACURA 12
# AUDI 12
# INTER 25
# ISUZU 10
# KENWO 5
# KIA 8
# OLDSM 1
# SUBAR 18
# VOLVO 12
# SATUR 2
# SMART 3
# INFIN 13
# PETER 1
#  5
# CITRO 1
# ROVER 5
# BUICK 5
# GEO 1
# MAZDA 5
# PORSC 3
# VOLKS 8
# YAMAH 1
# BSA 1
# MINI 1
# PONTI 1
# SPRI 1
# PLYMO 1
# SCION 2
# UPS 1
# FIAT 1
# UD 1
# UTILI 1
# GMCQ 1
# SAAB 2
# HINO 2
# STAR 1
# AM/T 1
# MI/F 1
# {None}
